# %%
import pandas as pd

# %% [markdown]
# # Batting Records

# %%
df_runs = pd.read_html("https://www.espncricinfo.com/records/trophy/batting-most-runs-career/world-cup-12")[0]

# %%
df_runs
# Out:
#                   Player       Span  Mat  Inns  NO  Runs    HS    Ave    BF  \
# 0     SR Tendulkar (IND)  1992-2011   45    44   4  2278   152  56.95  2560
# 1       RT Ponting (AUS)  1996-2011   46    42   4  1743  140*  45.86  2180
# 2          V Kohli (IND)  2011-2023   34    34   7  1573   107  58.25  1803
# 3     KC Sangakkara (SL)  2003-2015   37    35   8  1532   124  56.74  1770
# 4        DA Warner (AUS)  2015-2023  27*    27   2  1491   178  59.64  1484
# ..                   ...        ...  ...   ...  ..   ...   ...    ...   ...
# 145        AH Jones (NZ)  1987-1992   13    13   2   416    78  37.81   673
# 146      LRD Mendis (SL)  1975-1987   16    16   2   412    64  29.42   591
# 147      PN Kirsten (SA)  1992-1992    8     8   2   410    90  68.33   616
# 148   Fakhar Zaman (PAK)  2019-2023  12*    11   1   405  126*  40.50   397
# 149  KC Wessels (AUS/SA)  1983-1992   12    12   2   405    85  40.50   751
#
#          SR 100  50  0   4s  6s
# 0     88.98   6  15  2  241  27
# 1     79.95   5   6  1  145  31
# 2     87.24   4  10  1  141  11
# 3     86.55   5   7  1  147  14
# 4    100.47   6   5  -  152  37
# ..      ...  ..  .. ..  ...  ..
# 145   61.81   -   4  1   44   0
# 146   69.71   -   3  1   37   4
# 147   66.55   -   4  -   28   2
# 148  102.01   1   2  2   38  21
# 149   53.92   -   4  -   31   0
#
# [150 rows x 15 columns]

# %%
df_runs.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %%
df_runs.columns = df_runs.columns.str.lower()

# %%
df_runs.columns
# Out:
# Index(['player', 'span', 'mat', 'inns', 'no', 'runs', 'hs', 'ave', 'bf', 'sr',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df_runs.head()
# Out:
#                player       span  mat  inns  no  runs    hs    ave    bf  \
# 0  SR Tendulkar (IND)  1992-2011   45    44   4  2278   152  56.95  2560
# 1    RT Ponting (AUS)  1996-2011   46    42   4  1743  140*  45.86  2180
# 2       V Kohli (IND)  2011-2023   34    34   7  1573   107  58.25  1803
# 3  KC Sangakkara (SL)  2003-2015   37    35   8  1532   124  56.74  1770
# 4     DA Warner (AUS)  2015-2023  27*    27   2  1491   178  59.64  1484
#
#        sr 100  50  0   4s  6s
# 0   88.98   6  15  2  241  27
# 1   79.95   5   6  1  145  31
# 2   87.24   4  10  1  141  11
# 3   86.55   5   7  1  147  14
# 4  100.47   6   5  -  152  37

# %%
df_runs['country'] = df_runs['player'].str.split('(').str.get(1).str.replace(')','')

# %%
df_runs.head()
# Out:
#                player       span  mat  inns  no  runs    hs    ave    bf  \
# 0  SR Tendulkar (IND)  1992-2011   45    44   4  2278   152  56.95  2560
# 1    RT Ponting (AUS)  1996-2011   46    42   4  1743  140*  45.86  2180
# 2       V Kohli (IND)  2011-2023   34    34   7  1573   107  58.25  1803
# 3  KC Sangakkara (SL)  2003-2015   37    35   8  1532   124  56.74  1770
# 4     DA Warner (AUS)  2015-2023  27*    27   2  1491   178  59.64  1484
#
#        sr 100  50  0   4s  6s country
# 0   88.98   6  15  2  241  27     IND
# 1   79.95   5   6  1  145  31     AUS
# 2   87.24   4  10  1  141  11     IND
# 3   86.55   5   7  1  147  14      SL
# 4  100.47   6   5  -  152  37     AUS

# %%
df_runs['player'] = df_runs['player'].str.split('(').str.get(0)

# %%
df_runs.head()
# Out:
#            player       span  mat  inns  no  runs    hs    ave    bf      sr  \
# 0   SR Tendulkar   1992-2011   45    44   4  2278   152  56.95  2560   88.98
# 1     RT Ponting   1996-2011   46    42   4  1743  140*  45.86  2180   79.95
# 2        V Kohli   2011-2023   34    34   7  1573   107  58.25  1803   87.24
# 3  KC Sangakkara   2003-2015   37    35   8  1532   124  56.74  1770   86.55
# 4      DA Warner   2015-2023  27*    27   2  1491   178  59.64  1484  100.47
#
#   100  50  0   4s  6s country
# 0   6  15  2  241  27     IND
# 1   5   6  1  145  31     AUS
# 2   4  10  1  141  11     IND
# 3   5   7  1  147  14      SL
# 4   6   5  -  152  37     AUS

# %%
df_runs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   player   150 non-null    object
#  1   span     150 non-null    object
#  2   mat      150 non-null    object
#  3   inns     150 non-null    int64
#  4   no       150 non-null    int64
#  5   runs     150 non-null    int64
#  6   hs       150 non-null    object
#  7   ave      150 non-null    float64
#  8   bf       150 non-null    int64
#  9   sr       150 non-null    float64
#  10  100      150 non-null    object
#  11  50       150 non-null    object
#  12  0        150 non-null    object
#  13  4s       150 non-null    object
#  14  6s       150 non-null    object
#  15  country  150 non-null    object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 18.9+ KB

# %%
df_runs['mat'] = df_runs['mat'].str.replace('*','').astype('int')
df_runs['hs'] = df_runs['hs'].str.replace('*','').astype('int')

# %%
df_runs['50'] = df_runs['50'].replace('-',0).astype('int')
df_runs['100'] = df_runs['100'].replace('-',0).astype('int')

# %%
df_runs.head()
# Out:
#            player       span  mat  inns  no  runs   hs    ave    bf      sr  \
# 0   SR Tendulkar   1992-2011   45    44   4  2278  152  56.95  2560   88.98
# 1     RT Ponting   1996-2011   46    42   4  1743  140  45.86  2180   79.95
# 2        V Kohli   2011-2023   34    34   7  1573  107  58.25  1803   87.24
# 3  KC Sangakkara   2003-2015   37    35   8  1532  124  56.74  1770   86.55
# 4      DA Warner   2015-2023   27    27   2  1491  178  59.64  1484  100.47
#
#    100  50  0   4s  6s country
# 0    6  15  2  241  27     IND
# 1    5   6  1  145  31     AUS
# 2    4  10  1  141  11     IND
# 3    5   7  1  147  14      SL
# 4    6   5  -  152  37     AUS

# %%
df_runs['4s'] = df_runs['4s'].str.replace('+','').astype('int')
df_runs['6s'] = df_runs['6s'].str.replace('+','').astype('int')

# %%
df_runs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   player   150 non-null    object
#  1   span     150 non-null    object
#  2   mat      150 non-null    int32
#  3   inns     150 non-null    int64
#  4   no       150 non-null    int64
#  5   runs     150 non-null    int64
#  6   hs       150 non-null    int32
#  7   ave      150 non-null    float64
#  8   bf       150 non-null    int64
#  9   sr       150 non-null    float64
#  10  100      150 non-null    int32
#  11  50       150 non-null    int32
#  12  0        150 non-null    object
#  13  4s       150 non-null    int32
#  14  6s       150 non-null    int32
#  15  country  150 non-null    object
# dtypes: float64(2), int32(6), int64(4), object(4)
# memory usage: 15.4+ KB

# %%
df_runs = df_runs.reindex(columns=['player','country','span','mat','inns','no','runs','hs','ave','bf','sr',
                        '100','50','0','4s','6s'])

# %%
df_runs.head()
# Out:
#            player country       span  mat  inns  no  runs   hs    ave    bf  \
# 0   SR Tendulkar      IND  1992-2011   45    44   4  2278  152  56.95  2560
# 1     RT Ponting      AUS  1996-2011   46    42   4  1743  140  45.86  2180
# 2        V Kohli      IND  2011-2023   34    34   7  1573  107  58.25  1803
# 3  KC Sangakkara       SL  2003-2015   37    35   8  1532  124  56.74  1770
# 4      DA Warner      AUS  2015-2023   27    27   2  1491  178  59.64  1484
#
#        sr  100  50  0   4s  6s
# 0   88.98    6  15  2  241  27
# 1   79.95    5   6  1  145  31
# 2   87.24    4  10  1  141  11
# 3   86.55    5   7  1  147  14
# 4  100.47    6   5  -  152  37

# %%
# df_runs['hs'] = df_runs['hs'].str.replace('*','').astype('int')

# %%
df_runs.head()
# Out:
#            player country       span  mat  inns  no  runs   hs    ave    bf  \
# 0   SR Tendulkar      IND  1992-2011   45    44   4  2278  152  56.95  2560
# 1     RT Ponting      AUS  1996-2011   46    42   4  1743  140  45.86  2180
# 2        V Kohli      IND  2011-2023   34    34   7  1573  107  58.25  1803
# 3  KC Sangakkara       SL  2003-2015   37    35   8  1532  124  56.74  1770
# 4      DA Warner      AUS  2015-2023   27    27   2  1491  178  59.64  1484
#
#        sr  100  50  0   4s  6s
# 0   88.98    6  15  2  241  27
# 1   79.95    5   6  1  145  31
# 2   87.24    4  10  1  141  11
# 3   86.55    5   7  1  147  14
# 4  100.47    6   5  -  152  37

# %%
df_runs['0'] = df_runs['0'].replace("-",0)

# %%
df_runs.to_csv('dataset/batting_records.csv',index=False)

# %%
df_runs['player'] = df_runs['player'].str.strip()

# %%
df_runs[df_runs['player'] == 'RG Sharma']
# Out:
#       player country       span  mat  inns  no  runs   hs    ave    bf  \
# 5  RG Sharma     IND  2015-2023   25    25   2  1420  140  61.73  1379
#
#        sr  100  50  0   4s  6s
# 5  102.97    7   5  2  150  45

# %%
df_runs['0'] = df_runs['0'].astype('int')

# %%
df_runs['mat'].unique()
# Out:
# array([45, 46, 34, 37, 27, 25, 36, 23, 35, 38, 40, 26, 32, 31, 33, 21, 22,
#        30, 16, 18, 29, 17, 28, 20, 15, 19, 14, 13, 12,  9, 10, 11,  8,  7])

# %%
df_runs.groupby('player')[['player','sr']].max().sort_values('sr',ascending=False).head(10).reset_index(drop=True)
# Out:
#            player      sr
# 0      GJ Maxwell  161.51
# 1     BB McCullum  120.84
# 2       DA Miller  118.37
# 3      JC Buttler  118.20
# 4  AB de Villiers  117.29
# 5          JJ Roy  115.36
# 6     N Kapil Dev  115.14
# 7     DJ Mitchell  110.58
# 8        MR Marsh  108.85
# 9      R Ravindra  108.44

# %%
df_runs.head()
# Out:
#           player country       span  mat  inns  no  runs   hs    ave    bf  \
# 0   SR Tendulkar     IND  1992-2011   45    44   4  2278  152  56.95  2560
# 1     RT Ponting     AUS  1996-2011   46    42   4  1743  140  45.86  2180
# 2        V Kohli     IND  2011-2023   34    34   7  1573  107  58.25  1803
# 3  KC Sangakkara      SL  2003-2015   37    35   8  1532  124  56.74  1770
# 4      DA Warner     AUS  2015-2023   27    27   2  1491  178  59.64  1484
#
#        sr  100  50  0   4s  6s
# 0   88.98    6  15  2  241  27
# 1   79.95    5   6  1  145  31
# 2   87.24    4  10  1  141  11
# 3   86.55    5   7  1  147  14
# 4  100.47    6   5  0  152  37

# %%
df_runs.nlargest(n=5,columns='hs')[['player','country','hs']].sort_values('hs',ascending=True)
# Out:
#         player country   hs
# 25  SC Ganguly     IND  183
# 48   G Kirsten      SA  188
# 37  GJ Maxwell     AUS  201
# 9     CH Gayle      WI  215
# 28  MJ Guptill      NZ  237

# %%
df_runs.groupby('player')[['player','50']].sum(
        ).sort_values('50', ascending=False).head().reset_index(drop=True)
# Out:
#             player  50
# 0     SR Tendulkar  15
# 1  Shakib Al Hasan  11
# 2        SPD Smith  10
# 3          V Kohli  10
# 4        JH Kallis   9

# %%
df_runs[df_runs['runs'] == 2278]
# Out:
#          player country       span  mat  inns  no  runs   hs    ave    bf  \
# 0  SR Tendulkar     IND  1992-2011   45    44   4  2278  152  56.95  2560
#
#       sr  100  50  0   4s  6s
# 0  88.98    6  15  2  241  27

# %% [markdown]
# # Bowling Records

# %%
df_bowl = pd.read_html("https://www.espncricinfo.com/records/trophy/bowling-most-wickets-career/world-cup-12")[0]

# %%
df_bowl.head()
# Out:
#                Player       Span Mat  Inns  Balls  Overs  Mdns  Runs  Wkts  \
# 0    GD McGrath (AUS)  1996-2007  39    39   1955  325.5    42  1292    71
# 1  M Muralidaran (SL)  1996-2011  40    39   2061  343.3    15  1335    68
# 2      MA Starc (AUS)  2015-2023  26    26   1339  223.1     9  1165    59
# 3     SL Malinga (SL)  2007-2019  29    28   1394  232.2    11  1281    56
# 4   Wasim Akram (PAK)  1987-2003  38    36   1947  324.3    16  1311    55
#
#     BBI    Ave  Econ     SR  4  5
# 0  7/15  18.19  3.96  27.53  -  2
# 1  4/19  19.63  3.88  30.30  4  -
# 2  6/28  19.74  5.22  22.69  3  3
# 3  6/38  22.87  5.51  24.89  2  1
# 4  5/28  23.83  4.04  35.40  2  1

# %%
df_bowl['country'] = df_bowl.Player.str.split('(').str.get(1).str.replace(')','')

# %%
df_bowl.head()
# Out:
#                Player       Span Mat  Inns  Balls  Overs  Mdns  Runs  Wkts  \
# 0    GD McGrath (AUS)  1996-2007  39    39   1955  325.5    42  1292    71
# 1  M Muralidaran (SL)  1996-2011  40    39   2061  343.3    15  1335    68
# 2      MA Starc (AUS)  2015-2023  26    26   1339  223.1     9  1165    59
# 3     SL Malinga (SL)  2007-2019  29    28   1394  232.2    11  1281    56
# 4   Wasim Akram (PAK)  1987-2003  38    36   1947  324.3    16  1311    55
#
#     BBI    Ave  Econ     SR  4  5 country
# 0  7/15  18.19  3.96  27.53  -  2     AUS
# 1  4/19  19.63  3.88  30.30  4  -      SL
# 2  6/28  19.74  5.22  22.69  3  3     AUS
# 3  6/38  22.87  5.51  24.89  2  1      SL
# 4  5/28  23.83  4.04  35.40  2  1     PAK

# %%
df_bowl['Player'] = df_bowl['Player'].str.split('(').str.get(0).str.strip()

# %%
df_bowl.head()
# Out:
#           Player       Span Mat  Inns  Balls  Overs  Mdns  Runs  Wkts   BBI  \
# 0     GD McGrath  1996-2007  39    39   1955  325.5    42  1292    71  7/15
# 1  M Muralidaran  1996-2011  40    39   2061  343.3    15  1335    68  4/19
# 2       MA Starc  2015-2023  26    26   1339  223.1     9  1165    59  6/28
# 3     SL Malinga  2007-2019  29    28   1394  232.2    11  1281    56  6/38
# 4    Wasim Akram  1987-2003  38    36   1947  324.3    16  1311    55  5/28
#
#      Ave  Econ     SR  4  5 country
# 0  18.19  3.96  27.53  -  2     AUS
# 1  19.63  3.88  30.30  4  -      SL
# 2  19.74  5.22  22.69  3  3     AUS
# 3  22.87  5.51  24.89  2  1      SL
# 4  23.83  4.04  35.40  2  1     PAK

# %%
df_bowl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   100 non-null    object
#  1   Span     100 non-null    object
#  2   Mat      100 non-null    object
#  3   Inns     100 non-null    int64
#  4   Balls    100 non-null    int64
#  5   Overs    100 non-null    float64
#  6   Mdns     100 non-null    int64
#  7   Runs     100 non-null    int64
#  8   Wkts     100 non-null    int64
#  9   BBI      100 non-null    object
#  10  Ave      100 non-null    float64
#  11  Econ     100 non-null    float64
#  12  SR       100 non-null    float64
#  13  4        100 non-null    object
#  14  5        100 non-null    object
#  15  country  100 non-null    object
# dtypes: float64(4), int64(5), object(7)
# memory usage: 12.6+ KB

# %%
df_bowl['4'] = df_bowl['4'].replace('-',0).astype('int')

# %%
df_bowl['5'] = df_bowl['5'].replace('-',0).astype('int')

# %%
df_bowl.columns = df_bowl.columns.str.lower()

# %%
df_bowl.head()
# Out:
#           player       span mat  inns  balls  overs  mdns  runs  wkts   bbi  \
# 0     GD McGrath  1996-2007  39    39   1955  325.5    42  1292    71  7/15
# 1  M Muralidaran  1996-2011  40    39   2061  343.3    15  1335    68  4/19
# 2       MA Starc  2015-2023  26    26   1339  223.1     9  1165    59  6/28
# 3     SL Malinga  2007-2019  29    28   1394  232.2    11  1281    56  6/38
# 4    Wasim Akram  1987-2003  38    36   1947  324.3    16  1311    55  5/28
#
#      ave  econ     sr  4  5 country
# 0  18.19  3.96  27.53  0  2     AUS
# 1  19.63  3.88  30.30  4  0      SL
# 2  19.74  5.22  22.69  3  3     AUS
# 3  22.87  5.51  24.89  2  1      SL
# 4  23.83  4.04  35.40  2  1     PAK

# %%
df_bowl = df_bowl.reindex(columns=['player','country','span','mat','inns','balls','overs','mdns','runs','wkts','bbi',
                        'ave','econ','4','5'])

# %%
df_bowl.head()
# Out:
#           player country       span mat  inns  balls  overs  mdns  runs  wkts  \
# 0     GD McGrath     AUS  1996-2007  39    39   1955  325.5    42  1292    71
# 1  M Muralidaran      SL  1996-2011  40    39   2061  343.3    15  1335    68
# 2       MA Starc     AUS  2015-2023  26    26   1339  223.1     9  1165    59
# 3     SL Malinga      SL  2007-2019  29    28   1394  232.2    11  1281    56
# 4    Wasim Akram     PAK  1987-2003  38    36   1947  324.3    16  1311    55
#
#     bbi    ave  econ  4  5
# 0  7/15  18.19  3.96  0  2
# 1  4/19  19.63  3.88  4  0
# 2  6/28  19.74  5.22  3  3
# 3  6/38  22.87  5.51  2  1
# 4  5/28  23.83  4.04  2  1

# %%
df_bowl.to_csv("dataset/bowling_records.csv",index=False)

# %%
df_bowl.head()
# Out:
#           player country       span mat  inns  balls  overs  mdns  runs  wkts  \
# 0     GD McGrath     AUS  1996-2007  39    39   1955  325.5    42  1292    71
# 1  M Muralidaran      SL  1996-2011  40    39   2061  343.3    15  1335    68
# 2       MA Starc     AUS  2015-2023  26    26   1339  223.1     9  1165    59
# 3     SL Malinga      SL  2007-2019  29    28   1394  232.2    11  1281    56
# 4    Wasim Akram     PAK  1987-2003  38    36   1947  324.3    16  1311    55
#
#     bbi    ave  econ  4  5
# 0  7/15  18.19  3.96  0  2
# 1  4/19  19.63  3.88  4  0
# 2  6/28  19.74  5.22  3  3
# 3  6/38  22.87  5.51  2  1
# 4  5/28  23.83  4.04  2  1

# %%
df_bowl.nlargest(n=5,columns='runs')[['player','runs']]
# Out:
#              player  runs
# 10  Shakib Al Hasan  1551
# 1     M Muralidaran  1335
# 4       Wasim Akram  1311
# 0        GD McGrath  1292
# 3        SL Malinga  1281

# %%
df_bowl.head()
# Out:
#           player country       span mat  inns  balls  overs  mdns  runs  wkts  \
# 0     GD McGrath     AUS  1996-2007  39    39   1955  325.5    42  1292    71
# 1  M Muralidaran      SL  1996-2011  40    39   2061  343.3    15  1335    68
# 2       MA Starc     AUS  2015-2023  26    26   1339  223.1     9  1165    59
# 3     SL Malinga      SL  2007-2019  29    28   1394  232.2    11  1281    56
# 4    Wasim Akram     PAK  1987-2003  38    36   1947  324.3    16  1311    55
#
#     bbi    ave  econ  4  5
# 0  7/15  18.19  3.96  0  2
# 1  4/19  19.63  3.88  4  0
# 2  6/28  19.74  5.22  3  3
# 3  6/38  22.87  5.51  2  1
# 4  5/28  23.83  4.04  2  1

# %%
bowl = pd.read_csv('dataset/bowling_records.csv')

# %%
bowl.head()
# Out:
#           player country       span mat  inns  balls  overs  mdns  runs  wkts  \
# 0     GD McGrath     AUS  1996-2007  39    39   1955  325.5    42  1292    71
# 1  M Muralidaran      SL  1996-2011  40    39   2061  343.3    15  1335    68
# 2       MA Starc     AUS  2015-2023  26    26   1339  223.1     9  1165    59
# 3     SL Malinga      SL  2007-2019  29    28   1394  232.2    11  1281    56
# 4    Wasim Akram     PAK  1987-2003  38    36   1947  324.3    16  1311    55
#
#     bbi    ave  econ  4  5
# 0  7/15  18.19  3.96  0  2
# 1  4/19  19.63  3.88  4  0
# 2  6/28  19.74  5.22  3  3
# 3  6/38  22.87  5.51  2  1
# 4  5/28  23.83  4.04  2  1

# %%
bowl.nlargest(n=5,columns='econ')[['player','country','econ']]
# Out:
#                player country  econ
# 68       D Madushanka      SL  6.70
# 88          G Coetzee      SA  6.40
# 49  Mustafizur Rahman     BAN  6.37
# 38            A Zampa     AUS  5.82
# 58         AD Russell      WI  5.75

# %%
bowl[bowl['player'] == 'Mohammed Shami']
# Out:
#            player country       span mat  inns  balls  overs  mdns  runs  \
# 7  Mohammed Shami     IND  2015-2023  15    15    733  122.1    12   599
#
#    wkts   bbi    ave  econ  4  5
# 7    47  5/18  12.74   4.9  4  3

# %%
bowl['year_one'] = bowl.span.str.split('-').str.get(0).astype('int')

# %%
bowl['year_two'] = bowl.span.str.split('-').str.get(1).astype('int')

# %%
bowl.head()
# Out:
#           player country       span mat  inns  balls  overs  mdns  runs  wkts  \
# 0     GD McGrath     AUS  1996-2007  39    39   1955  325.5    42  1292    71
# 1  M Muralidaran      SL  1996-2011  40    39   2061  343.3    15  1335    68
# 2       MA Starc     AUS  2015-2023  26    26   1339  223.1     9  1165    59
# 3     SL Malinga      SL  2007-2019  29    28   1394  232.2    11  1281    56
# 4    Wasim Akram     PAK  1987-2003  38    36   1947  324.3    16  1311    55
#
#     bbi    ave  econ  4  5  year_one  year_two
# 0  7/15  18.19  3.96  0  2      1996      2007
# 1  4/19  19.63  3.88  4  0      1996      2011
# 2  6/28  19.74  5.22  3  3      2015      2023
# 3  6/38  22.87  5.51  2  1      2007      2019
# 4  5/28  23.83  4.04  2  1      1987      2003

# %%
bowl['year_diff'] = bowl['year_two'] - bowl['year_one']

# %%
bowl.head()
# Out:
#           player country       span mat  inns  balls  overs  mdns  runs  wkts  \
# 0     GD McGrath     AUS  1996-2007  39    39   1955  325.5    42  1292    71
# 1  M Muralidaran      SL  1996-2011  40    39   2061  343.3    15  1335    68
# 2       MA Starc     AUS  2015-2023  26    26   1339  223.1     9  1165    59
# 3     SL Malinga      SL  2007-2019  29    28   1394  232.2    11  1281    56
# 4    Wasim Akram     PAK  1987-2003  38    36   1947  324.3    16  1311    55
#
#     bbi    ave  econ  4  5  year_one  year_two  year_diff
# 0  7/15  18.19  3.96  0  2      1996      2007         11
# 1  4/19  19.63  3.88  4  0      1996      2011         15
# 2  6/28  19.74  5.22  3  3      2015      2023          8
# 3  6/38  22.87  5.51  2  1      2007      2019         12
# 4  5/28  23.83  4.04  2  1      1987      2003         16

# %%
bowl.nsmallest(n=5,columns='wkts')[['player','country','wkts']]
# Out:
#         player country  wkts
# 85  RGD Willis     ENG    18
# 86    UT Yadav     IND    18
# 87    Umar Gul     PAK    18
# 88   G Coetzee      SA    18
# 89     A Nehra     IND    18
